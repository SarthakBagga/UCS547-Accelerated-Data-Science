# %%
import numpy as np

# %%
# 1. Reverse the NumPy array
arr = np.array([1, 2, 3, 6, 4, 5])
reversed_arr = arr[::-1]
print("Reversed array:", reversed_arr)
# Out:
# Reversed array: [5 4 6 3 2 1]

# %%
# 2. Compare the following numpy arrays
arr1 = np.array([[1, 2], [3, 4]])
arr2 = np.array([[1, 2], [3, 4]])

# %%
comparison = np.array_equal(arr1, arr2)
print("Are arr1 and arr2 equal?", comparison)
# Out:
# Are arr1 and arr2 equal? True

# %%
# 3. Find the most frequent value and their indices

# i.
x = np.array([1, 2, 3, 4, 5, 1, 2, 1, 1, 1])
values_x, counts_x = np.unique(x, return_counts=True)
most_frequent_x = values_x[np.argmax(counts_x)]
indices_x = np.where(x == most_frequent_x)

print("Most frequent value in x:", most_frequent_x)
print("Indices of most frequent value in x:", indices_x)
# Out:
# Most frequent value in x: 1
# Indices of most frequent value in x: (array([0, 5, 7, 8, 9], dtype=int64),)
